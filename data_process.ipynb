# %%
import pandas as pd
import numpy as np
import json

# %%
color_5 = "#0378A6"
color_10 = "#FAC858"
color_15 = "#EE6666"

# %%
skill_network = {
                                "categories": [
                                    {
                                        "name": "Computer",
                                        "base": "Computer"
                                    },
                                    {
                                        "name": "Research Methods",
                                        "base": "Research Methods"
                                    }
                                ],
                                "nodes": [
                                    {
                                        "name": "Computer",
                                        "value": 15,
                                        "color": "#BF0B3B",
                                        "category": 0
                                    },
                                    {
                                        "name": "Research Methods",
                                        "value": 15,
                                        "color": "#BF0B3B",
                                        "category": 1
                                    },
                                    {
                                        "name": "Data Analysis",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "Graphics",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "Modeling and Simulation",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "Python",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "TensorFlow",
                                        "value": 5,
                                        "color": "#F27405",
                                        "category": 0
                                    },
                                    {
                                        "name": "Pytorch",
                                        "value": 5,
                                        "color": "#F27405",
                                        "category": 0
                                    },
                                    {
                                        "name": "R",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "JavaScript",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "HTML",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "Julia",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "ArcGIS",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "NetLogo",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "GEE",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 0
                                    },
                                    {
                                        "name": "Machine Learning",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 1
                                    },
                                    {
                                        "name": "Deep Learning",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 1
                                    },
                                    {
                                        "name": "Complex Networks",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 1
                                    },
                                    {
                                        "name": "Spatial Algorithms",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 1
                                    },
                                    {
                                        "name": "Web Spider & Geospatial Web Data Visualization",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 1
                                    },
                                    {
                                        "name": "Advanced Statistics",
                                        "value": 10,
                                        "color": "#238C2A",
                                        "category": 1
                                    }
                                ],
                                "links": [
                                    { "source": "Data Analysis", "target": "Computer" },
                                    { "source": "Graphics", "target": "Computer" },
                                    { "source": "Modeling and Simulation", "target": "Computer" },
                                    { "source": "Python", "target": "Computer" },
                                    { "source": "TensorFlow", "target": "Python" },
                                    { "source": "Pytorch", "target": "Python" },
                                    { "source": "R", "target": "Computer" },
                                    { "source": "JavaScript", "target": "Computer" },
                                    { "source": "HTML", "target": "Computer" },
                                    { "source": "Julia", "target": "Computer" },
                                    { "source": "ArcGIS", "target": "Computer" },
                                    { "source": "NetLogo", "target": "Computer" },
                                    { "source": "GEE", "target": "Computer" },
                                    { "source": "Machine Learning", "target": "Research Methods" },
                                    { "source": "Deep Learning", "target": "Research Methods" },
                                    { "source": "Complex Networks", "target": "Research Methods" },
                                    { "source": "Spatial Algorithms", "target": "Research Methods" },
                                    { "source": "Web Spider & Geospatial Web Data Visualization", "target": "Research Methods" },
                                    { "source": "Advanced Statistics", "target": "Research Methods" },
                                    {  "source": "Computer", "target": "Research Methods"}
                                ]
                            }

# %%
# 将nodes里的value值为5的color换成color_5，其他同理
for node in skill_network["nodes"]:
    if node["value"] == 5:
        node["color"] = color_5
    elif node["value"] == 10:
        node["color"] = color_10
    else:
        node["color"] = color_15

# %%
# 将skill_network保存为json文件
with open("skill_network.json", "w") as f:
    json.dump(skill_network, f, ensure_ascii=False, indent=4)
